# %%
import sys
import os

sys.path.append(os.path.dirname(os.getcwd()))

# %%
from svk.io._database import Database

database = Database("C:/src/6svk/examples/Example-RP.xlsx")
database.read()
print(len(database))
# Out:
# 2

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\geer\AppData\Local\miniforge3\envs\svk\python.exe
