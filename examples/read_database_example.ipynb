# %%
import sys
import os

sys.path.append(os.path.dirname(os.getcwd()))

# %%
from svk.io.readdatabase import DataBase

database = DataBase("C:/src/6svk/examples/Example-RP.xlsx")
database.read()
print(len(database))
# Out:
# 2
